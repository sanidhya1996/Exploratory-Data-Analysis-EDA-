# %% [markdown]
# <a href="https://colab.research.google.com/github/sanidhya1996/Exploratory-Data-Analysis-EDA-/blob/main/Play_Store_App_Review_analysis(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis
# ![f1fc1b90-0c33-11ed-aeff-e413d8b37a7a.cf.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##### **Project Type**    - EDA( Exploratory Data Analysis)
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
#
#
# In summary, the initial analysis of the dataset reveals interesting insights that can guide the client's business objectives before the start of the project. The 'Game' category dominates the Play Store with the highest number of apps, followed by 'Family' and 'Sports' categories. It is noteworthy that the majority of apps in the Play Store are free, indicating the importance of offering free options to attract users.
#
# The content rating distribution shows that apps targeting a wide age group, such as 'Everyone' and 'Teen,' are the most prevalent. Additionally, a significant number of apps have a rating of 4.4, followed by ratings of 4.5 and 4.2, suggesting a positive user experience for these apps.
#
# The analysis of installs indicates that the 'Communication' category has the highest number of installs, followed by 'Social' and 'News and Magazines' categories. This information can help the client understand the popularity of different app categories and align their business objectives accordingly.
#
# Examining reviews, positive reviews comprise the majority, indicating a high level of user satisfaction. The categories of 'Auto and Vehicles' and 'Games' receive the highest ratings, suggesting positive user feedback and satisfaction within these categories. Additionally, the 'Social' category stands out with the highest number of reviews, indicating a high level of user interaction and feedback.
#
# Considering genres, 'Communication' is the genre with the highest number of installs, followed by 'Social' and 'News and Magazines.' 'Sports' emerges as the genre with the highest number of apps, followed by 'Action' and 'Health and Fitness,' highlighting the popularity of these genres.
#
# Analyzing the Android version vs. installs plot, it becomes evident that apps compatible with a wide range of Android devices, denoted as 'Varies with device,' attract the highest number of installs. This underscores the importance of ensuring compatibility across various Android versions to maximize the user base.
#
# Lastly, the correlation analysis reveals interesting relationships between different factors. Most columns exhibit negative correlations, while the 'install' and 'reviews' columns are positively correlated. The price of an app influences various factors, such as ratings, reviews, installs, and sentiment polarity.
#
# These preliminary insights can help the client set their business objectives by understanding the app market landscape, identifying popular categories and genres, and considering factors such as app pricing and Android compatibility. By leveraging these insights, the client can make informed decisions and develop strategies to maximize their success in the Play Store.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
# https://github.com/sanidhya1996/Exploratory-Data-Analysis-EDA-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# The Play Store is a massive digital marketplace with  more than 100,000 of apps available for download. For app developers and businesses looking to reach a large audience, the Play Store represents a huge opportunity. However, with so many apps available, it can be difficult to stand out and attract users. In order to be successful on the Play Store, it's important to understand what factors contribute to an app's success.
#
# The problem we aim to address in this project is to explore the Play Store data to identify the key factors that contribute to an app's success, such as the category, content rating, number of installs, and user reviews. By analyzing these factors, we hope to provide insights and recommendations that can help app developers and businesses increase their visibility and downloads on the Play Store.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.:-The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.Each app (row) has values for catergory, rating, size, and more.
# Another dataset contains customer reviews of the android apps.Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Importing Libraries of Numpy and Pandas.
import numpy as np
import pandas as pd
# Importing Libraries for Data Visualisation.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive

drive.mount('/content/drive')

# Importing the Dataset through the Path in drive
df =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/projects/Play Store Data.csv")
User_df =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/projects/User Reviews.csv")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
User_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# Merging the Two datasets by inner joining.
Psd = df.merge(User_df, how = 'inner', on = 'App')
Psd.head()
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Psd.shape
# Out:
# (122662, 17)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Psd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122662 entries, 0 to 122661
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   App                     122662 non-null  object
#  1   Category                122662 non-null  object
#  2   Rating                  122622 non-null  float64
#  3   Reviews                 122662 non-null  object
#  4   Size                    122662 non-null  object
#  5   Installs                122662 non-null  object
#  6   Type                    122662 non-null  object
#  7   Price                   122662 non-null  object
#  8   Content Rating          122662 non-null  object
#  9   Genres                  122662 non-null  object
#  10  Last Updated            122662 non-null  object
#  11  Current Ver             122662 non-null  object
#  12  Android Ver             122662 non-null  object
#  13  Translated_Review       72605 non-null   object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(Psd[Psd.duplicated()])
# Out:
# 81001

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
Psd.isna().sum()
# Out:
# App                           0
# Category                      0
# Rating                       40
# Reviews                       0
# Size                          0
# Installs                      0
# Type                          0
# Price                         0
# Content Rating                0
# Genres                        0
# Last Updated                  0
# Current Ver                   0
# Android Ver                   0
# Translated_Review         50057
# Sentiment                 50047
# Sentiment_Polarity        50047
# Sentiment_Subjectivity    50047
# dtype: int64

# %%
# Visualizing the missing values
# Visualizing the missing values
missing = pd.DataFrame((Psd.isnull().sum())*100/Psd.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index',y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here:--There are two dataset provided and i have merged them together.after merging them together there are 122662 rows and 17 column consisting of object and float data types. There are 81001 duplicate values present in the dataset. Four columns have 50047 null values each.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(Psd.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
Psd.describe()
# Out:
#               Rating  Sentiment_Polarity  Sentiment_Subjectivity
# count  122622.000000        72615.000000            72615.000000
# mean        4.322405            0.157320                0.494162
# std         0.284766            0.332652                0.240144
# min         2.500000           -1.000000                0.000000
# 25%         4.200000            0.000000                0.380000
# 50%         4.400000            0.129167                0.509740
# 75%         4.500000            0.356250                0.633333
# max         4.900000            1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# -->App - It tells us about the name of the application with a short description (optional).
#
# -->Category - It gives the Category the app belongs to.
#
# -->Rating - It contains the average rating the respective app received from its users.
#
# -->Reviews - It tells us about the total number of users who have given a review for the application.
#
# -->Size - It tells us about the size being occupied the application on the mobile phone.
#
# -->Installs - It tells us about the total number of installs/downloads for an application.
#
# -->Type - IIt states whether an app is free to use or paid.
#
# -->Price - It gives the price payable to install the app. For free type apps, the price is zero.
#
# -->Content Rating - It states whether or not an app is suitable for all age groups or not.
#
# -->Genres - It tells us about the various other categories to which an application can belong.
#
# -->Last Updated - It tells us about the when the application was updated.
#
# -->Current Ver - It tells us about the current version of the application.
#
# -->Android Ver - It tells us about the android version which can support the application on its platform.
#
# -->Translated Review Column - Displays reviews translated into another language.
#
# -->Sentiment Column- Shows emotional tone (positive/negative/neutral) in text.
#
# -->Sentiment Polarity Column - Indicates sentiment direction (positive/negative/neutral).
#
# -->Sentiment Subjectivity Column - Measures degree of personal opinion in sentiment.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
Psd.nunique()
# Out:
# App                        1020
# Category                     33
# Rating                       23
# Reviews                    1330
# Size                        178
# Installs                     13
# Type                          2
# Price                        14
# Content Rating                5
# Genres                       73
# Last Updated                299
# Current Ver                 598
# Android Ver                  25
# Translated_Review         26682
# Sentiment                     3
# Sentiment_Polarity         5295
# Sentiment_Subjectivity     4382
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Transforming the 'Reviews' column from Object type to float type.
Psd['Reviews'] = Psd['Reviews'].astype(float)


# Removing '$' in the 'Price' column and transforming into Float Datatype.
Psd['Price'] = Psd['Price'].apply(lambda x: str(x).replace('$','') if '$' in str(x) else str(x))
Psd['Price'] = Psd['Price'].apply(lambda x : float(x))


# Cleaning the Data of 'Installs' and transforming into numeric.
Psd['Installs'] = Psd['Installs'].map(lambda x: (x.rstrip('+')))
Psd['Installs'] = Psd['Installs'].map(lambda x: ''.join(x.split(',')))
Psd['Installs'] = pd.to_numeric(Psd['Installs'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here:-I transformed the review column from object ot float type and install column to numeric and rmoved '$' from the price column and transformed it to float

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1:-  Number of Apps per Category

# %%
# Chart - 1 visualization code
# Countplot for Category column,which has a Number of Apps Per Category
plt.figure(figsize=(15,7))
sns.countplot(x='Category',data=Psd)
plt.title('Number of Apps per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. Beacause this chart is easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-From the aove visualisation, the 'Game' Category has a most number of Apps in Playstore with 28360 Applications.
#
# Similarly, the second most Number of Applications in the list is 'Family' Category with 9947 Applications in Playstore.
#
# And, the Third one is 'Sports' Category which has a 8840 Applications in the Playstore.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-  Yes, the gained insight will help in creating a positive business impact
# The app category and number of installs can provide several business-related insights, such as:
#
# Identifying the most popular app categories: The number of installs for each app category can help businesses understand which app categories are most popular among users. This information can be used by businesses to develop and market their apps accordingly.
#
# Identifying potential opportunities: By analyzing the app categories and number of installs, businesses can identify potential opportunities for developing new apps or improving existing ones.
#
# Understanding user behavior: The number of installs for each app category can also provide insights into user behavior. For example, businesses can determine which app categories users tend to download and use the most, and develop strategies to increase engagement and retention.
#
# Competitive analysis: By comparing the number of installs for different app categories, businesses can gain insights into their competition and understand where they stand in the market.

# %% [markdown]
# #### Chart - 2:-Number of Apps Paid and Free in Percentage

# %%
# Chart - 2 visualization code
# Visualising the Type data through Pieplot.
cost_df = Psd['Type'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(cost_df,labels = ['Free','Paid'], colors = ['Gold','Red'],autopct='%.1f%%',textprops={'fontsize': 10} )
plt.title("Number of Apps Paid and Free in Percentage",size=20)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Because this gives better visualization for this particular column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:- From the Visual Data, we found that Most of Applications in Playstore are Free.
# And, The Percentage Of Free Apps are 98.7% and 1.3% are Paid Applications in PlayStore.
#
# Finally, we found that more than 90% Applications in the Playstore are Free to Install.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:- Yes, the gained insight will help in creating a positive business impact this graph clearly shows that most of the users prefer using  free app over the paid apps

# %% [markdown]
# #### Chart - 3:- Top Content Rating Apps in Playstore

# %%
# Chart - 3 visualization code
# Visualising the data by sorting the content Rating.
Psd['Content Rating'].value_counts().plot.bar(figsize=(15,6),color = 'aquamarine')
plt.xlabel('Content Rating')
plt.ylabel('Number of apps')
plt.title('Top Content Rating Apps in Playstore')
plt.xticks(rotation=45)
plt.legend()
Psd['Content Rating'].value_counts()
# Out:
# Everyone           89635
# Teen               17440
# Everyone 10+        8060
# Mature 17+          7487
# Adults only 18+       40
# Name: Content Rating, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Because it gives a better visualization of the column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-We found that Majority of content rating in playstore apps are Everyone, means user can be at any age limit.
#
# --> And Respectively, the second majority is Teen with 17440 apps and Third is 8060 apps with Everyone10+ age limit

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-Yes, the gained insight will help in creating a positive business impact.if we observe that there is a high number of apps rated for everyone, it may indicate that the market demands more family-friendly apps. Similarly, if we see a high number of apps rated for mature audiences, it may indicate a trend towards more adult-oriented content. This information can be valuable for businesses looking to develop and market apps to specific target audiences. Additionally, understanding the distribution of content ratings can help businesses identify any gaps in the market and opportunities for growth.

# %% [markdown]
# #### Chart - 4:-Sorted rating of apps in Playstore

# %%
# Chart - 4 visualization code
# Visualising the sorted Rating for the Number of Apps.
Psd['Rating'].value_counts().plot.bar(figsize=(15,6),color=['C4', 'g', 'c', 'orange', 'm', 'r'])
plt.xlabel('Sorted rating')
plt.ylabel('Number of apps')
plt.title('Sorted rating of apps in Playstore')
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Because this charts shows the trend of the column better

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-From the above beautiful insight, we found that '4.4' rating is there for the most number of apps in the playstore.
#
# --> Respectively, '4.4', '4.5','4.2' are the next top rating for the apps in the playstore.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-Yes, the gained insight help in creating a positive business impact.Based on the rating and number of apps, we can gain some business insights such as:
#
# User satisfaction: Higher ratings could indicate higher user satisfaction with the app, which could lead to more user engagement and retention.
#
# Market demand: By analyzing the number of apps and their ratings, businesses can gain insights into which app categories are in high demand among users, and which ones might be oversaturated.
#
# Competition: By comparing the ratings and number of apps across different competitors, businesses can gain insights into how they stack up against their competition and identify areas for improvement.
#
# App quality: Higher ratings could indicate that the app is of higher quality, which could increase user trust in the brand and lead to better business outcomes.

# %% [markdown]
# #### Chart - 5:- Which category got maximum Installs

# %%
# Chart - 5 visualization code
fig,ax=plt.subplots(figsize=(20,7))
ax=sns.barplot(data=Psd,x='Category',y='Installs',color = 'Black' )
ax.set_title('Which category got maximum Installs')
for bar in ax.patches:
    ax.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=6, xytext=(0, 8),
                   textcoords='offset points')
    plt.xticks(rotation = 90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:-Because this chart helps in better visualization understanding the trend of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:- From the above analysis, we find that 'Communication' Category has the most number of installs in the *playstore*.
#
# --> And, 'Social' is at second most installed category.
#
# --> Respectively, 'News and magazines' category is the third most in top installs in playstore.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-Yes, the gained insight help in creating a positive business impact like High installation rates for certain categories can indicate a high demand for those types of apps. This could suggest an opportunity for developers to create and market more apps in those categories. and The relationship between category and installs can also provide insights into consumer preferences and behavior. For example, if we observe that certain categories tend to have higher install rates than others, we can infer that users are more interested in those types of apps. This information can be useful in developing marketing strategies and targeting specific user demographics.

# %% [markdown]
# #### Chart - 6:- Count of Sentiment

# %%
# Chart - 6 visualization code
# Finding the Number of 'Sentiment' Value counts.
Psd['Sentiment'].value_counts().plot.bar(figsize=(15,6),color=['Green','Red','Orange'])
plt.title("Count of Sentiment ")
plt.xlabel("Sentiment")
plt.ylabel("No.of Reviews")
plt.show()
print(Psd['Sentiment'].value_counts())
# Out:
# Positive    46195
# Negative    18134
# Neutral      8286
# Name: Sentiment, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.:Because this chart gives best visualization and understanding

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-The Number of Positive reviews are '46195'. the Number of Negative reviews are '18134'. the Number of Neutral reviews are '8286'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-Yes the gained insight will help in creating a positive business impact the sentiment of the reviews can give businesses an idea of how their users feel about their app. Positive sentiments indicate that the app is well-liked by its users, while negative sentiments suggest areas for improvement. This information can help businesses identify user pain points and take steps to improve their app's performance, user experience, and overall customer satisfaction.

# %% [markdown]
# #### Chart - 7:-  Reviews of Users in Sentiment Analysis

# %%
# Chart - 7 visualization code
# Visualising the 'Sentiment' Column with Plotting the Pie Chart to get beautiful insights.
data = list(Psd['Sentiment'].value_counts())
labels = 'Positive','Negative','Neutral'
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(10,10))
plt.pie(data,labels= labels, colors = colors, autopct="%.1f%%",explode=[0.02, 0.02, 0.02])
plt.title(" Reviews of Users in Sentiment Analysis",size=20)
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:-This chart gives the best visualization to that particular column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here :-From the Above visualisation, we got the percentage of reviews with pie chart. And Here, Positive reviews has 63.6%, Negative reviews has 25.0% and Neutral reviews has 11.4% in total reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-The business related insight we can take from the above line is that the majority of the reviews for the app are positive, with 63.6% being positive and only 25.0% being negative. This indicates that the app has a good overall reputation among users. However, it is also important to note the 11.4% of reviews that are neutral, as this may indicate that there are areas for improvement that the app developers can focus on.

# %% [markdown]
# #### Chart - 8:- Which Category got maximum rating

# %%
# Chart - 8 visualization code
fig,ax = plt.subplots(figsize=(20,7))
ax = sns.barplot(data=Psd, x ='Category', y ='Rating', palette=['red','pink'] )
ax.set_title('Which Category got maximum rating')
# Add ratings at the top of the bars
for bar in ax.containers[0]:
    ax.annotate(format(bar.get_height(), '.2f'), (bar.get_x() + bar.get_width() / 2., bar.get_height()),
                ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:- A bar plot is a visualization that represents categorical data using rectangular bars. It is commonly used to display and compare the values of different categories or groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-According to the information provided, the categories "Auto and Vehicles" and "Games" have the highest ratings, with "Auto and Vehicles" having a rating of 4.54 and "Games" having a rating of 4.46. Following closely is the category "Health and Fitness" with a rating of 4.43.
#
# It's important to note that these ratings represent the average ratings within each category based on the available data. Higher ratings indicate that the apps in those categories have received positive reviews and user feedback, suggesting a higher level of user satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-The gained insights about the high ratings in certain categories can potentially have a positive business impact. Here's how:
#
# * Positive Business Impact:
#
# Auto and Vehicles, Games, and Health and Fitness categories have high ratings, indicating a higher level of user satisfaction. This suggests that there is a positive perception and acceptance of apps within these categories.
# Businesses operating in these categories can leverage the high ratings to attract more users, gain customer trust, and potentially increase app downloads or usage.
# Positive user reviews and high ratings can contribute to a positive brand image, word-of-mouth recommendations, and enhanced customer loyalty.
#
# * Negative Growth Insights:
#
# From the information provided, there are no specific insights indicating negative growth. However, it's important to analyze other aspects such as app download numbers, user engagement, and competition to assess the full picture.
# Negative growth could occur if a particular category has declining app downloads, decreasing user engagement, or faces strong competition that leads to decreased market share.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

plt.figure(figsize=(20, 8))
barplot = sns.barplot(data=Psd, x='Category', y='Reviews')
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Reviews')
plt.title('Which category got maximum review')

# Add labels on top of the bars
for bar in barplot.patches:
    height = bar.get_height()
    barplot.annotate(format(height, '.0f'), (bar.get_x() + bar.get_width() / 2., height),
                     ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:-
# A barplot is a type of data visualization that uses rectangular bars to represent data. The bars are typically plotted vertically, with the height of each bar representing the value of a variable. Barplots can be used to compare different categories of data, or to track changes in data over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-In terms of the number of reviews, the category "Social" stands out with a significant count of 13,859,074 reviews. The second-highest category in terms of reviews is "Games" with 5,373,110 reviews. Following closely is the category "Photography" with a count of 3,186,719 reviews.
#
# These numbers indicate the popularity and user engagement within these categories based on the review counts. The "Social" category appears to have a substantial number of reviews, suggesting a high level of user interaction and feedback. The "Games" and "Photography" categories also exhibit notable engagement levels based on the considerable number of reviews they have received.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-The gained insights regarding the high number of reviews in the "Social," "Games," and "Photography" categories can potentially have a positive business impact. Here's how:
#
# * Positive Business Impact:
#
# * High number of reviews in the "Social," "Games," and "Photography" categories indicate a significant level of user engagement and interest in apps within these categories.
# * Businesses operating in these categories can leverage the high review counts to gain insights into user preferences, improve their apps, and enhance user satisfaction.
# * Positive user reviews and high engagement can contribute to increased downloads, user retention, and brand loyalty.
# * It provides an opportunity for businesses to analyze the reviews and identify areas for improvement or innovation based on user feedback.
#
# * Negative Growth Insights:
#
# * There are no specific insights provided that indicate negative growth. However, it's essential to consider other factors such as app ratings, user churn rate, and market competition to assess the potential negative impact on growth.
#
# * Negative growth could occur if there is a decline in the number of reviews over time, indicating decreasing user engagement or interest.
#
# * Additionally, if competing apps within these categories receive significantly higher review counts or exhibit better user satisfaction, it may negatively impact the growth of other apps in the same category.

# %% [markdown]
# #### Chart - 10:- Which Genres got maximum Installs

# %%
# Chart - 10 visualization code
fig,ax=plt.subplots(figsize=(30,7))
ax=sns.barplot(data=Psd,x='Genres',y='Installs',color = 'pink' )
ax.set_title('Which Genres got maximum Installs')
for bar in ax.patches:
    ax.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=6, xytext=(0, 8),
                   textcoords='offset points')
    plt.xticks(rotation = 90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:-
# A barplot is a type of data visualization that uses rectangular bars to represent data. The bars are typically plotted vertically, with the height of each bar representing the value of a variable. Barplots can be used to compare different categories of data, or to track changes in data over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-
# The genre "Communication" has the highest number of installs, indicating its popularity among users. It is followed by the genres "Social" and "News and Magazines," which also have significant numbers of installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-The insights gained from the popularity of the "Communication," "Social," and "News and Magazines" genres can potentially create a positive business impact. These genres have a significant number of installs, indicating a strong demand from users. Businesses operating within these genres can leverage this information to develop innovative solutions, attract a larger user base, and drive positive growth.
#
# However, it is important to consider other factors such as competition, user satisfaction, and evolving trends to ensure sustained growth. By continuously monitoring user feedback, analyzing market trends, and delivering exceptional user experiences, businesses can stay competitive, drive positive growth, and maintain a favorable impact on their business.

# %% [markdown]
# #### Chart - 11:-Top Genres in the Playstore

# %%
# Chart - 11 visualization code

plt.figure(figsize=(20,6))
ax = sns.countplot(x="Genres", data=Psd, palette= ['cyan','blue'],order=Psd['Genres'].value_counts().index[:30])
plt.title('Top Genres in the Playstore')
plt.xticks(rotation = 90)
for bar in ax.patches:
    ax.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=7, xytext=(0, 8),
                   textcoords='offset points')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:-
# A barplot is a type of data visualization that uses rectangular bars to represent data. The bars are typically plotted vertically, with the height of each bar representing the value of a variable. Barplots can be used to compare different categories of data, or to track changes in data over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-The genre with the highest number of apps is "Sports," which boasts a total of 10,920 apps. Following closely is the genre "Action" with 8,580 apps, while "Health and Fitness" ranks next with 6,562 apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-The gained insights regarding the distribution of apps across different genres can potentially have a positive business impact. Here's the analysis:
#
# Positive Business Impact:
#
# * The high number of apps in the "Sports" genre indicates a strong market demand for sports-related content, games, and services. Businesses operating in this genre can leverage this insight to develop innovative apps, attract a larger user base, and generate revenue through various monetization strategies.
# * The significant number of apps in the "Action" genre suggests a thriving market for action-oriented games and entertainment. Businesses in this genre can capitalize on the popularity of action-based experiences to attract users, drive engagement, and monetize their offerings.
# * The presence of a considerable number of apps in the "Health and Fitness" genre reflects the growing interest in personal well-being and fitness-related activities. Businesses can leverage this insight to develop health and fitness apps, offer premium services or subscriptions, and tap into the health-conscious user base.
#
# Negative Growth Insights:
#
# * The insights provided do not indicate specific negative growth factors. However, it's crucial to consider other aspects such as competition, user satisfaction, and evolving market trends.
# * Negative growth could occur if a particular genre becomes oversaturated with apps, leading to increased competition and challenges in standing out among the competition.

# %% [markdown]
# #### Chart - 12:- Which Android Ver got maximum Installs

# %%
# Chart - 12 visualization code
fig,ax=plt.subplots(figsize=(26,7))
ax=sns.barplot(data=Psd,x='Android Ver',y='Installs',color = 'purple' )
ax.set_title('Which Android Ver got maximum Installs')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:-A bar plot is a visualization that represents categorical data using rectangular bars. It is commonly used to display and compare the values of different categories or groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-
# Based on the Android version vs. installs plot, it is evident that the "Varies with device" category has the highest number of installs. This suggests that apps that are compatible with a wide range of Android devices, regardless of the specific version, tend to attract a larger user base.
#
# Following the "Varies with device" category, the Android version "4.1 and up" has the next highest number of installs. This indicates that a significant portion of users have devices running Android 4.1 or newer, and apps compatible with this version and higher have gained popularity.
#
# Additionally, the Android version "4.4 and up" also exhibits a notable number of installs, implying a substantial user base with devices running Android 4.4 or newer.
#
# These insights highlight the importance of app compatibility with various Android versions. Ensuring compatibility with a wide range of devices and targeting newer Android versions can be beneficial for reaching a larger user base and maximizing the number of app installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:-The gained insights regarding the Android version vs. installs plot can potentially have a positive business impact. Here's the analysis:
#
# Positive Business Impact:
#
# * Understanding that the "Varies with device" category has the highest number of installs can help businesses prioritize developing apps that are compatible with a wide range of Android devices. This ensures a broader reach and maximizes the potential user base.
# * Recognizing the popularity of the "4.1 and up" Android version indicates that targeting this version and newer can be advantageous. Businesses can focus on developing features and optimizing their apps to cater to the user base with devices running this Android version.
# * The notable number of installs for the "4.4 and up" Android version suggests the importance of ensuring compatibility with this version and newer. It may be beneficial for businesses to prioritize testing and optimizing their apps for this specific Android version.
#
# Negative Growth Insights:
#
# * There are no specific insights provided that indicate negative growth. However, it's essential to consider other factors such as competition, user satisfaction, and evolving technology trends to evaluate potential negative impacts.
# * Negative growth could occur if businesses fail to adapt to newer Android versions, resulting in compatibility issues and limited access to a larger user base.
# * Additionally, if businesses neglect the "Varies with device" category and limit compatibility to specific Android versions, they may exclude a significant portion of potential users and experience negative growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
data_corr= Psd.corr()
plt.figure(figsize=(12,9))
sns.heatmap(data_corr, cmap='mako', linewidths=0.1, annot=True, linecolor='white')
# Out:
# <ipython-input-28-e3e9ed990e9a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr= Psd.corr()
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.:-A correlation heatmap is a graphical representation of the correlation between different features in a dataset. It displays a matrix of colored squares, with each square representing the correlation between two features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-From the above correlation heatmap we can see that most of the columns are negatively correlated to each other and the columns install and reviews are the two most positively correlated column.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Visualising the Pairplot for each pair of columns with the hue 'Type'.
plt.figure(figsize=(7,7))
sns.pairplot(Psd, hue='Type',palette=('black','red'), markers=["D","s"])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.:- Pair plots are useful for identifying trends, patterns, and relationships between different variables in a dataset. They can help to identify potential outliers or errors in the data, as well as reveal any underlying correlations or dependencies between variables. Overall, pair plots are a powerful tool for exploratory data analysis and can provide valuable insights into complex datasets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:-Most of the column are affected or we can say influenced by the price column those apps that are free have better ratings as compared to the paid apps,free apps have more number of reviews as compared to the paid ones,
# free apps have more number of installs as compared to the paid and sentiment polarity is more positive for the free apps then the paid ones.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here:-
# Based on the insights gathered, here are a few suggestions for the client to achieve their business objectives:
#
# 1.Focus on Popular Categories: The client should consider developing and promoting apps in popular categories such as "Games," "Communication," "Social," and "Sports" to capitalize on their high number of installs. These categories have shown significant user engagement and demand.
#
# 2.Emphasize Free Apps: Since the majority of apps in the Play Store are free, the client should prioritize offering free apps to align with user preferences. By monetizing through alternative methods such as advertisements, in-app purchases, or premium features, the client can generate revenue while still attracting a larger user base.
#
# 3.Target All Age Groups: With a majority of apps rated as "Everyone," the client has the opportunity to target a wide range of age groups. However, it's important to ensure that app content and features are appropriate and appealing to users of different age ranges, including teenagers and Everyone10+.
#
# 4.Prioritize Positive User Reviews: Given the high percentage of positive reviews, the client should focus on delivering exceptional user experiences, addressing user feedback, and continuously improving app quality. Encouraging users to leave positive reviews and responding to negative feedback can enhance app ratings and attract more users.
#
# 5.Optimize for Android Compatibility: Considering the popularity of the "Varies with device" category and Android versions like "4.1 and up" and "4.4 and up," the client should ensure app compatibility across a wide range of devices and target the newer Android versions. This will help maximize the potential user base and increase app installs.
#
# 6.Leverage Pricing Strategies: Based on the insights that free apps have better ratings, more reviews, and higher installs, the client should carefully consider pricing strategies. Offering free apps with optional in-app purchases or premium features can attract more users and potentially generate revenue.
#
# Overall, the client should prioritize user satisfaction, market trends, and ongoing app improvements to achieve their business objectives. By leveraging the insights gained from the data analysis, the client can make informed decisions, develop successful app strategies, and drive positive business impact in the competitive app market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
#
# In conclusion, the analysis of the provided visualizations and insights reveals several important findings for the Play Store app market. Here is a summary of the key conclusions:
#
# * App Categories: The "Game" category has the highest number of apps, followed by "Family" and "Sports" categories. This suggests that gaming and family-oriented apps have a significant presence in the Play Store.
#
# * Pricing: The majority of apps in the Play Store are free, accounting for approximately 98.7% of the total. Only a small percentage (1.3%) of apps are paid. This indicates that offering free apps is the prevailing strategy in the Play Store.
#
# * Content Rating: The majority of apps in the Play Store have a content rating of "Everyone," indicating that they are suitable for users of all age groups. The second most common rating is "Teen," followed by "Everyone10+."
#
# * App Ratings: The rating "4.4" appears most frequently among the apps in the Play Store, followed by "4.5" and "4.2." This indicates that many apps have received positive ratings from users.
#
# * App Installs: The "Communication" category has the highest number of installs, followed by "Social" and "News and Magazines" categories. This suggests that apps related to communication, social networking, and news are popular among users.
#
# * Reviews: Positive reviews constitute the majority (63.6%), followed by negative reviews (25.0%) and neutral reviews (11.4%). This indicates a generally positive sentiment among users.
#
# * App Genre and Installs: The genre "Sports" has the highest number of apps, while the genre "Communication" has the most installs. This suggests that the "Sports" genre has a significant number of apps but may not have as high user engagement as the "Communication" genre.
#
# * Android Compatibility: Apps that are compatible with a wide range of Android devices ("Varies with device") have the highest number of installs. Additionally, targeting newer Android versions, particularly "4.1 and up" and "4.4 and up," can enhance the potential user base.
#
# * Correlation Analysis: The correlation heatmap reveals negative correlations between most columns and positive correlations between the "install" and "reviews" columns. Furthermore, app characteristics such as ratings, reviews, installs, and sentiment polarity are influenced by the pricing strategy, with free apps generally performing better in these metrics.
#
# Based on these conclusions, it is recommended that businesses focus on popular categories, prioritize free app offerings, optimize for compatibility with a wide range of Android devices, and pay attention to user ratings and sentiment. By aligning their strategies with these insights, businesses can improve their chances of success and positive business impact in the competitive Play Store market.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
